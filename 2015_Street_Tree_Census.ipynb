# %% [markdown]
# <a href="https://colab.research.google.com/github/sayidbek-bakhrom/CNN-for-skin-cancer-detection/blob/main/2015_Street_Tree_Census.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Exploration

# %%
import pandas as pd

# %%
tree_census = pd.read_csv('/content/2015_Street_Tree_Census_-_Tree_Data_20251218.csv')

# %%
tree_census.head()
# Out:
#    tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status health  \
# 0   180683    348711  08/27/2015         3           0   OnCurb  Alive   Fair
# 1   200540    315986  09/03/2015        21           0   OnCurb  Alive   Fair
# 2   204026    218365  09/05/2015         3           0   OnCurb  Alive   Good
# 3   204337    217969  09/05/2015        10           0   OnCurb  Alive   Good
# 4   189565    223043  08/30/2015        21           0   OnCurb  Alive   Good
#
#                             spc_latin       spc_common  ...    boro_ct  \
# 0                         Acer rubrum        red maple  ...  4,073,900
# 1                   Quercus palustris          pin oak  ...  4,097,300
# 2  Gleditsia triacanthos var. inermis      honeylocust  ...  3,044,900
# 3  Gleditsia triacanthos var. inermis      honeylocust  ...  3,044,900
# 4                     Tilia americana  American linden  ...  3,016,500
#
#       state   latitude  longitude           x_sp          y_sp  \
# 0  New York  40.723092 -73.844215  1,027,431.148  202,756.7687
# 1  New York  40.794111 -73.818679  1,034,455.701  228,644.8374
# 2  New York  40.717581 -73.936608  1,001,822.831  200,716.8913
# 3  New York  40.713537 -73.934456  1,002,420.358  199,244.2531
# 4  New York  40.666778 -73.975979    990,913.775   182,202.426
#
#   council district census tract        bin           bbl
# 0             29.0          739  4052307.0  4.022210e+09
# 1             19.0          973  4101931.0  4.044750e+09
# 2             34.0          449  3338310.0  3.028870e+09
# 3             34.0          449  3338342.0  3.029250e+09
# 4             39.0          165  3025654.0  3.010850e+09
#
# [5 rows x 45 columns]

# %%
pd.set_option('display.max_columns', None)

# %%
tree_census.head()
# Out:
#    tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status health  \
# 0   180683    348711  08/27/2015         3           0   OnCurb  Alive   Fair
# 1   200540    315986  09/03/2015        21           0   OnCurb  Alive   Fair
# 2   204026    218365  09/05/2015         3           0   OnCurb  Alive   Good
# 3   204337    217969  09/05/2015        10           0   OnCurb  Alive   Good
# 4   189565    223043  08/30/2015        21           0   OnCurb  Alive   Good
#
#                             spc_latin       spc_common steward guards  \
# 0                         Acer rubrum        red maple     NaN    NaN
# 1                   Quercus palustris          pin oak     NaN    NaN
# 2  Gleditsia triacanthos var. inermis      honeylocust    1or2    NaN
# 3  Gleditsia triacanthos var. inermis      honeylocust     NaN    NaN
# 4                     Tilia americana  American linden     NaN    NaN
#
#    sidewalk         user_type problems root_stone root_grate root_other  \
# 0  NoDamage  TreesCount Staff      NaN         No         No         No
# 1    Damage  TreesCount Staff   Stones        Yes         No         No
# 2    Damage         Volunteer      NaN         No         No         No
# 3    Damage         Volunteer   Stones        Yes         No         No
# 4    Damage         Volunteer   Stones        Yes         No         No
#
#   trunk_wire trnk_light trnk_other brch_light brch_shoe brch_other  \
# 0         No         No         No         No        No         No
# 1         No         No         No         No        No         No
# 2         No         No         No         No        No         No
# 3         No         No         No         No        No         No
# 4         No         No         No         No        No         No
#
#              address  postcode      zip_city  community board  borocode  \
# 0  108-005 70 AVENUE     11375  Forest Hills              406         4
# 1   147-074 7 AVENUE     11357    Whitestone              407         4
# 2  390 MORGAN AVENUE     11211      Brooklyn              301         3
# 3  1027 GRAND STREET     11211      Brooklyn              301         3
# 4       603 6 STREET     11215      Brooklyn              306         3
#
#     borough  cncldist  st_assem  st_senate   nta            nta_name  \
# 0    Queens        29        28         16  QN17        Forest Hills
# 1    Queens        19        27         11  QN49          Whitestone
# 2  Brooklyn        34        50         18  BK90   East Williamsburg
# 3  Brooklyn        34        53         18  BK90   East Williamsburg
# 4  Brooklyn        39        44         21  BK37  Park Slope-Gowanus
#
#      boro_ct     state   latitude  longitude           x_sp          y_sp  \
# 0  4,073,900  New York  40.723092 -73.844215  1,027,431.148  202,756.7687
# 1  4,097,300  New York  40.794111 -73.818679  1,034,455.701  228,644.8374
# 2  3,044,900  New York  40.717581 -73.936608  1,001,822.831  200,716.8913
# 3  3,044,900  New York  40.713537 -73.934456  1,002,420.358  199,244.2531
# 4  3,016,500  New York  40.666778 -73.975979    990,913.775   182,202.426
#
#    council district census tract        bin           bbl
# 0              29.0          739  4052307.0  4.022210e+09
# 1              19.0          973  4101931.0  4.044750e+09
# 2              34.0          449  3338310.0  3.028870e+09
# 3              34.0          449  3338342.0  3.029250e+09
# 4              39.0          165  3025654.0  3.010850e+09

# %%
tree_census.columns
# Out:
# Index(['tree_id', 'block_id', 'created_at', 'tree_dbh', 'stump_diam',
#        'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
#        'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other', 'address', 'postcode',
#        'zip_city', 'community board', 'borocode', 'borough', 'cncldist',
#        'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct', 'state',
#        'latitude', 'longitude', 'x_sp', 'y_sp', 'council district',
#        'census tract', 'bin', 'bbl'],
#       dtype='object')

# %%
tree_census_subset = tree_census[['tree_id', 'tree_dbh', 'stump_diam',
       'curb_loc', 'status', 'health', 'spc_latin', 'steward', 'sidewalk', 'problems', 'root_stone',
       'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
       'brch_light', 'brch_shoe', 'brch_other']]
tree_census_subset.head()
# Out:
#    tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0   180683         3           0   OnCurb  Alive   Fair
# 1   200540        21           0   OnCurb  Alive   Fair
# 2   204026         3           0   OnCurb  Alive   Good
# 3   204337        10           0   OnCurb  Alive   Good
# 4   189565        21           0   OnCurb  Alive   Good
#
#                             spc_latin steward  sidewalk problems root_stone  \
# 0                         Acer rubrum     NaN  NoDamage      NaN         No
# 1                   Quercus palustris     NaN    Damage   Stones        Yes
# 2  Gleditsia triacanthos var. inermis    1or2    Damage      NaN         No
# 3  Gleditsia triacanthos var. inermis     NaN    Damage   Stones        Yes
# 4                     Tilia americana     NaN    Damage   Stones        Yes
#
#   root_grate root_other trunk_wire trnk_light trnk_other brch_light brch_shoe  \
# 0         No         No         No         No         No         No        No
# 1         No         No         No         No         No         No        No
# 2         No         No         No         No         No         No        No
# 3         No         No         No         No         No         No        No
# 4         No         No         No         No         No         No        No
#
#   brch_other
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No

# %%
tree_census_subset.isna().sum()
# Out:
# tree_id            0
# tree_dbh           0
# stump_diam         0
# curb_loc           0
# status             0
# health         31616
# spc_latin      31619
# steward       519438
# sidewalk       31616
# problems      457944
# root_stone         0
# root_grate         0
# root_other         0
# trunk_wire         0
# trnk_light         0
# trnk_other         0
# brch_light         0
# brch_shoe          0
# brch_other         0
# dtype: int64

# %%
tree_census_subset[tree_census_subset['health'].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 37       211205         0          16          OnCurb  Stump    NaN       NaN
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 239      203597         0          15          OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 683693   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683695   170888         0           5          OnCurb  Stump    NaN       NaN
# 683697   177922         0          17          OnCurb  Stump    NaN       NaN
# 683698   193791         3           0          OnCurb   Dead    NaN       NaN
# 683699   172660         0           4          OnCurb  Stump    NaN       NaN
#
#        steward sidewalk problems root_stone root_grate root_other trunk_wire  \
# 37         NaN      NaN      NaN         No         No         No         No
# 57         NaN      NaN      NaN         No         No         No         No
# 196        NaN      NaN      NaN         No         No         No         No
# 209        NaN      NaN      NaN         No         No         No         No
# 239        NaN      NaN      NaN         No         No         No         No
# ...        ...      ...      ...        ...        ...        ...        ...
# 683693     NaN      NaN      NaN         No         No         No         No
# 683695     NaN      NaN      NaN         No         No         No         No
# 683697     NaN      NaN      NaN         No         No         No         No
# 683698     NaN      NaN      NaN         No         No         No         No
# 683699     NaN      NaN      NaN         No         No         No         No
#
#        trnk_light trnk_other brch_light brch_shoe brch_other
# 37             No         No         No        No         No
# 57             No         No         No        No         No
# 196            No         No         No        No         No
# 209            No         No         No        No         No
# 239            No         No         No        No         No
# ...           ...        ...        ...       ...        ...
# 683693         No         No         No        No         No
# 683695         No         No         No        No         No
# 683697         No         No         No        No         No
# 683698         No         No         No        No         No
# 683699         No         No         No        No         No
#
# [31616 rows x 19 columns]

# %%
tree_census_subset.describe()
# Out:
#              tree_id       tree_dbh     stump_diam
# count  683788.000000  683788.000000  683788.000000
# mean   365205.011085      11.279787       0.432463
# std    208122.092902       8.723042       3.290241
# min         3.000000       0.000000       0.000000
# 25%    186582.750000       4.000000       0.000000
# 50%    366214.500000       9.000000       0.000000
# 75%    546170.250000      16.000000       0.000000
# max    722694.000000     450.000000     140.000000

# %%
tree_census_subset.dtypes
# Out:
# tree_id        int64
# tree_dbh       int64
# stump_diam     int64
# curb_loc      object
# status        object
# health        object
# spc_latin     object
# steward       object
# sidewalk      object
# problems      object
# root_stone    object
# root_grate    object
# root_other    object
# trunk_wire    object
# trnk_light    object
# trnk_other    object
# brch_light    object
# brch_shoe     object
# brch_other    object
# dtype: object

# %%
tree_census_subset.hist(bins=60, figsize=(20, 10))
# Out:
# array([[<Axes: title={'center': 'tree_id'}>,
#         <Axes: title={'center': 'tree_dbh'}>],
#        [<Axes: title={'center': 'stump_diam'}>, <Axes: >]], dtype=object)

# %%
tree_census_subset[tree_census_subset['tree_dbh']>50]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 2405     168583       425           0          OnCurb  Alive   Good
# 3738     199546        51           0          OnCurb  Alive   Good
# 4887     139665        72           0  OffsetFromCurb  Alive   Good
# 6724     209349       122           0          OnCurb  Alive   Good
# 10083    215075       169           0          OnCurb  Alive   Good
# ...         ...       ...         ...             ...    ...    ...
# 675265   179496        52           0  OffsetFromCurb  Alive   Good
# 677954   166796        54           0          OnCurb  Alive   Good
# 679894   169501        51           0          OnCurb  Alive   Good
# 681736   179366       281           0          OnCurb  Alive   Fair
# 682788   183910       127           0          OnCurb   Dead    NaN
#
#                                  spc_latin steward  sidewalk      problems  \
# 2405                       Quercus bicolor    1or2    Damage           NaN
# 3738                      Acer saccharinum     NaN  NoDamage        Stones
# 4887                      Acer saccharinum     NaN  NoDamage           NaN
# 6724                     Quercus palustris     NaN    Damage           NaN
# 10083   Gleditsia triacanthos var. inermis     NaN  NoDamage           NaN
# ...                                    ...     ...       ...           ...
# 675265                   Quercus palustris     NaN    Damage        Stones
# 677954                    Acer saccharinum     NaN  NoDamage        Stones
# 679894                        Quercus alba     NaN  NoDamage  BranchLights
# 681736                   Quercus palustris     NaN    Damage           NaN
# 682788                                 NaN     NaN       NaN           NaN
#
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 2405           No         No         No         No         No         No
# 3738          Yes         No         No         No         No         No
# 4887           No         No         No         No         No         No
# 6724           No         No         No         No         No         No
# 10083          No         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 675265        Yes         No         No         No         No         No
# 677954        Yes         No         No         No         No         No
# 679894         No         No         No         No         No         No
# 681736         No         No         No         No         No         No
# 682788         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other
# 2405           No        No         No
# 3738           No        No         No
# 4887           No        No         No
# 6724           No        No         No
# 10083          No        No         No
# ...           ...       ...        ...
# 675265         No        No         No
# 677954         No        No         No
# 679894        Yes        No         No
# 681736         No        No         No
# 682788         No        No         No
#
# [364 rows x 19 columns]

# %%
large_trees = tree_census_subset[tree_census_subset['tree_dbh']>50]

# %%
large_trees[['tree_id', 'tree_dbh']].plot(kind='scatter', x='tree_id', y='tree_dbh', figsize=(20, 10))
# Out:
# <Axes: xlabel='tree_id', ylabel='tree_dbh'>

# %%
large_trees = tree_census_subset[tree_census_subset['stump_diam']>50]

# %%
large_trees[['tree_id', 'stump_diam']].plot(kind='scatter', x='tree_id', y='stump_diam', figsize=(20, 10))
# Out:
# <Axes: xlabel='tree_id', ylabel='stump_diam'>

# %%
pd.DataFrame(tree_census_subset['spc_latin'].value_counts()).plot(kind='bar', figsize=(20, 10))
# Out:
# <Axes: xlabel='spc_latin'>

# %%
tree_census_subset['steward'].value_counts()
# Out:
# steward
# 1or2       143557
# 3or4        19183
# 4orMore      1610
# Name: count, dtype: int64

# %%
tree_census_subset['sidewalk'].value_counts()
# Out:
# sidewalk
# NoDamage    464978
# Damage      187194
# Name: count, dtype: int64

# %%
tree_census_subset['curb_loc'].value_counts()
# Out:
# curb_loc
# OnCurb            656896
# OffsetFromCurb     26892
# Name: count, dtype: int64

# %%
stumps = tree_census_subset[tree_census_subset['status']=='Stump']

# %%
stumps
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 37       211205         0          16   OnCurb  Stump    NaN       NaN
# 239      203597         0          15   OnCurb  Stump    NaN       NaN
# 641      179766         0          30   OnCurb  Stump    NaN       NaN
# 644      180619         0          10   OnCurb  Stump    NaN       NaN
# 646      208828         0          15   OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...      ...    ...    ...       ...
# 683348   152836         0          13   OnCurb  Stump    NaN       NaN
# 683686   191219         0          25   OnCurb  Stump    NaN       NaN
# 683695   170888         0           5   OnCurb  Stump    NaN       NaN
# 683697   177922         0          17   OnCurb  Stump    NaN       NaN
# 683699   172660         0           4   OnCurb  Stump    NaN       NaN
#
#        steward sidewalk problems root_stone root_grate root_other trunk_wire  \
# 37         NaN      NaN      NaN         No         No         No         No
# 239        NaN      NaN      NaN         No         No         No         No
# 641        NaN      NaN      NaN         No         No         No         No
# 644        NaN      NaN      NaN         No         No         No         No
# 646        NaN      NaN      NaN         No         No         No         No
# ...        ...      ...      ...        ...        ...        ...        ...
# 683348     NaN      NaN      NaN         No         No         No         No
# 683686     NaN      NaN      NaN         No         No         No         No
# 683695     NaN      NaN      NaN         No         No         No         No
# 683697     NaN      NaN      NaN         No         No         No         No
# 683699     NaN      NaN      NaN         No         No         No         No
#
#        trnk_light trnk_other brch_light brch_shoe brch_other
# 37             No         No         No        No         No
# 239            No         No         No        No         No
# 641            No         No         No        No         No
# 644            No         No         No        No         No
# 646            No         No         No        No         No
# ...           ...        ...        ...       ...        ...
# 683348         No         No         No        No         No
# 683686         No         No         No        No         No
# 683695         No         No         No        No         No
# 683697         No         No         No        No         No
# 683699         No         No         No        No         No
#
# [17654 rows x 19 columns]

# %%
deads = tree_census_subset[tree_census_subset['status']=='Dead']
deads
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 266      210544         6           0          OnCurb   Dead    NaN       NaN
# 285      188609         9           0          OnCurb   Dead    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 682816   184342        11           0          OnCurb   Dead    NaN       NaN
# 682823   155430         2           0          OnCurb   Dead    NaN       NaN
# 683346   156566        10           0          OnCurb   Dead    NaN       NaN
# 683693   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683698   193791         3           0          OnCurb   Dead    NaN       NaN
#
#        steward sidewalk problems root_stone root_grate root_other trunk_wire  \
# 57         NaN      NaN      NaN         No         No         No         No
# 196        NaN      NaN      NaN         No         No         No         No
# 209        NaN      NaN      NaN         No         No         No         No
# 266        NaN      NaN      NaN         No         No         No         No
# 285        NaN      NaN      NaN         No         No         No         No
# ...        ...      ...      ...        ...        ...        ...        ...
# 682816     NaN      NaN      NaN         No         No         No         No
# 682823     NaN      NaN      NaN         No         No         No         No
# 683346     NaN      NaN      NaN         No         No         No         No
# 683693     NaN      NaN      NaN         No         No         No         No
# 683698     NaN      NaN      NaN         No         No         No         No
#
#        trnk_light trnk_other brch_light brch_shoe brch_other
# 57             No         No         No        No         No
# 196            No         No         No        No         No
# 209            No         No         No        No         No
# 266            No         No         No        No         No
# 285            No         No         No        No         No
# ...           ...        ...        ...       ...        ...
# 682816         No         No         No        No         No
# 682823         No         No         No        No         No
# 683346         No         No         No        No         No
# 683693         No         No         No        No         No
# 683698         No         No         No        No         No
#
# [13961 rows x 19 columns]

# %%
tree_census_subset.columns
# Out:
# Index(['tree_id', 'tree_dbh', 'stump_diam', 'curb_loc', 'status', 'health',
#        'spc_latin', 'steward', 'sidewalk', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other'],
#       dtype='object')

# %% [markdown]
# # Data Cleaning

# %%
tree_problems = tree_census_subset[['root_stone',
       'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
       'brch_light', 'brch_shoe', 'brch_other']]
tree_problems
# Out:
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 0              No         No         No         No         No         No
# 1             Yes         No         No         No         No         No
# 2              No         No         No         No         No         No
# 3             Yes         No         No         No         No         No
# 4             Yes         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 683783         No         No         No         No         No         No
# 683784         No         No         No         No         No         No
# 683785         No         No         No         No         No         No
# 683786         No         No         No         No         No         No
# 683787         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other
# 0              No        No         No
# 1              No        No         No
# 2              No        No         No
# 3              No        No         No
# 4              No        No         No
# ...           ...       ...        ...
# 683783         No        No         No
# 683784         No        No         No
# 683785         No        No         No
# 683786         No        No         No
# 683787         No        No         No
#
# [683788 rows x 9 columns]

# %%
tree_census_subset['health'].value_counts()
# Out:
# health
# Good    528850
# Fair     96504
# Poor     26818
# Name: count, dtype: int64

# %%
tree_problems.apply(pd.Series.value_counts)
# Out:
#      root_stone  root_grate  root_other  trunk_wire  trnk_light  trnk_other  \
# No       543789      680252      653466      670514      682757      651215
# Yes      139999        3536       30322       13274        1031       32573
#
#      brch_light  brch_shoe  brch_other
# No       621423     683377      659433
# Yes       62365        411       24355

# %%
mask = ((tree_census_subset['status'] == 'Stump') | (tree_census_subset['status'] == 'Dead'))

# %%
tree_census_subset.loc[mask] = tree_census_subset.loc[mask].fillna('Not Applicable')

# %%
tree_census_subset[tree_census_subset['status']=='Dead']
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status          health  \
# 57       187807         0           0          OnCurb   Dead  Not Applicable
# 196      208322        10           0          OnCurb   Dead  Not Applicable
# 209      209058         6           0          OnCurb   Dead  Not Applicable
# 266      210544         6           0          OnCurb   Dead  Not Applicable
# 285      188609         9           0          OnCurb   Dead  Not Applicable
# ...         ...       ...         ...             ...    ...             ...
# 682816   184342        11           0          OnCurb   Dead  Not Applicable
# 682823   155430         2           0          OnCurb   Dead  Not Applicable
# 683346   156566        10           0          OnCurb   Dead  Not Applicable
# 683693   156162         3           0  OffsetFromCurb   Dead  Not Applicable
# 683698   193791         3           0          OnCurb   Dead  Not Applicable
#
#              spc_latin         steward        sidewalk        problems  \
# 57      Not Applicable  Not Applicable  Not Applicable  Not Applicable
# 196     Not Applicable  Not Applicable  Not Applicable  Not Applicable
# 209     Not Applicable  Not Applicable  Not Applicable  Not Applicable
# 266     Not Applicable  Not Applicable  Not Applicable  Not Applicable
# 285     Not Applicable  Not Applicable  Not Applicable  Not Applicable
# ...                ...             ...             ...             ...
# 682816  Not Applicable  Not Applicable  Not Applicable  Not Applicable
# 682823  Not Applicable  Not Applicable  Not Applicable  Not Applicable
# 683346  Not Applicable  Not Applicable  Not Applicable  Not Applicable
# 683693  Not Applicable  Not Applicable  Not Applicable  Not Applicable
# 683698  Not Applicable  Not Applicable  Not Applicable  Not Applicable
#
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 57             No         No         No         No         No         No
# 196            No         No         No         No         No         No
# 209            No         No         No         No         No         No
# 266            No         No         No         No         No         No
# 285            No         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 682816         No         No         No         No         No         No
# 682823         No         No         No         No         No         No
# 683346         No         No         No         No         No         No
# 683693         No         No         No         No         No         No
# 683698         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other
# 57             No        No         No
# 196            No        No         No
# 209            No        No         No
# 266            No        No         No
# 285            No        No         No
# ...           ...       ...        ...
# 682816         No        No         No
# 682823         No        No         No
# 683346         No        No         No
# 683693         No        No         No
# 683698         No        No         No
#
# [13961 rows x 19 columns]

# %%
tree_census_subset.isna().sum()
# Out:
# tree_id            0
# tree_dbh           0
# stump_diam         0
# curb_loc           0
# status             0
# health             1
# spc_latin          5
# steward       487823
# sidewalk           1
# problems      426329
# root_stone         0
# root_grate         0
# root_other         0
# trunk_wire         0
# trnk_light         0
# trnk_other         0
# brch_light         0
# brch_shoe          0
# brch_other         0
# dtype: int64

# %%
tree_census_subset[tree_census_subset['sidewalk'].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 346299   540677         7           0  OffsetFromCurb  Alive   Good
#
#                                  spc_latin steward sidewalk problems  \
# 346299  Gleditsia triacanthos var. inermis     NaN      NaN      NaN
#
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 346299         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other
# 346299         No        No         No

# %%
tree_census_subset[tree_census_subset['health'].isna()]
# Out:
#        tree_id  tree_dbh  stump_diam curb_loc status health  \
# 32889   245041        16           0   OnCurb  Alive    NaN
#
#                     spc_latin steward sidewalk problems root_stone root_grate  \
# 32889  Fraxinus pennsylvanica     NaN   Damage      NaN         No         No
#
#       root_other trunk_wire trnk_light trnk_other brch_light brch_shoe  \
# 32889         No         No         No         No         No        No
#
#       brch_other
# 32889         No

# %%
tree_census_subset['problems'].value_counts()
# Out:
# problems
# Stones                                                                          95673
# Not Applicable                                                                  31615
# BranchLights                                                                    29452
# Stones,BranchLights                                                             17808
# RootOther                                                                       11418
#                                                                                 ...
# Stones,MetalGrates,WiresRope,TrunkLights,TrunkOther,BranchLights,BranchOther        1
# WiresRope,BranchLights,Sneakers                                                     1
# MetalGrates,WiresRope,TrunkLights                                                   1
# Stones,RootOther,TrunkLights,TrunkOther,BranchOther                                 1
# MetalGrates,TrunkOther,Sneakers                                                     1
# Name: count, Length: 232, dtype: int64

# %%
tree_census_subset['problems'].fillna('Stones', inplace=True)
tree_census_subset['health'].fillna('Good', inplace=True)
tree_census_subset['spc_latin'].fillna('No Observation', inplace=True)
tree_census_subset['sidewalk'].fillna('NoDamage', inplace=True)
# Out:
# /tmp/ipython-input-1222917511.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tree_census_subset['problems'].fillna('Stones', inplace=True)
# /tmp/ipython-input-1222917511.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_census_subset['problems'].fillna('Stones', inplace=True)
# /tmp/ipython-input-1222917511.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tree_census_subset['health'].fillna('Good', inplace=True)
# /tmp/ipython-input-1222917511.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_census_subset['health'].fillna('Good', inplace=True)
# /tmp/ipython-input-1222917511.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tree_census_subset['spc_latin'].fillna('No Observation', inplace=True)
# /tmp/ipython-input-1222917511.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_census_subset['spc_latin'].fillna('No Observation', inplace=True)
# /tmp/ipython-input-1222917511.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tree_census_subset['sidewalk'].fillna('NoDamage', inplace=True)
# /tmp/ipython-input-1222917511.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_census_subset['sidewalk'].fillna('NoDamage', inplace=True)

# %%
tree_census_subset['steward'].fillna('1or2', inplace=True)
# Out:
# /tmp/ipython-input-844228979.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tree_census_subset['steward'].fillna('1or2', inplace=True)
# /tmp/ipython-input-844228979.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_census_subset['steward'].fillna('1or2', inplace=True)

# %%
tree_census_subset.isna().sum()
# Out:
# tree_id       0
# tree_dbh      0
# stump_diam    0
# curb_loc      0
# status        0
# health        0
# spc_latin     0
# steward       0
# sidewalk      0
# problems      0
# root_stone    0
# root_grate    0
# root_other    0
# trunk_wire    0
# trnk_light    0
# trnk_other    0
# brch_light    0
# brch_shoe     0
# brch_other    0
# dtype: int64

# %%
large_trees = tree_census_subset[(tree_census_subset['tree_dbh']>60) | (tree_census_subset['stump_diam']>60)]
large_trees
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status          health  \
# 2405     168583       425           0          OnCurb  Alive            Good
# 4887     139665        72           0  OffsetFromCurb  Alive            Good
# 6466     166008         0          72          OnCurb  Stump  Not Applicable
# 6724     209349       122           0          OnCurb  Alive            Good
# 7042     206818         0         100          OnCurb  Stump  Not Applicable
# ...         ...       ...         ...             ...    ...             ...
# 667425   151958        66           0  OffsetFromCurb  Alive            Fair
# 673105   165324        79           0          OnCurb  Alive            Good
# 674016   184879       105           0          OnCurb  Alive            Fair
# 681736   179366       281           0          OnCurb  Alive            Fair
# 682788   183910       127           0          OnCurb   Dead  Not Applicable
#
#                                  spc_latin         steward        sidewalk  \
# 2405                       Quercus bicolor            1or2          Damage
# 4887                      Acer saccharinum            1or2        NoDamage
# 6466                        Not Applicable  Not Applicable  Not Applicable
# 6724                     Quercus palustris            1or2          Damage
# 7042                        Not Applicable  Not Applicable  Not Applicable
# ...                                    ...             ...             ...
# 667425                       Quercus rubra            1or2        NoDamage
# 673105  Gleditsia triacanthos var. inermis            1or2          Damage
# 674016                       Ginkgo biloba            1or2          Damage
# 681736                   Quercus palustris            1or2          Damage
# 682788                      Not Applicable  Not Applicable  Not Applicable
#
#               problems root_stone root_grate root_other trunk_wire trnk_light  \
# 2405            Stones         No         No         No         No         No
# 4887            Stones         No         No         No         No         No
# 6466    Not Applicable         No         No         No         No         No
# 6724            Stones         No         No         No         No         No
# 7042    Not Applicable         No         No         No         No         No
# ...                ...        ...        ...        ...        ...        ...
# 667425          Stones         No         No         No         No         No
# 673105          Stones        Yes         No         No         No         No
# 674016          Stones        Yes         No         No         No         No
# 681736          Stones         No         No         No         No         No
# 682788  Not Applicable         No         No         No         No         No
#
#        trnk_other brch_light brch_shoe brch_other
# 2405           No         No        No         No
# 4887           No         No        No         No
# 6466           No         No        No         No
# 6724           No         No        No         No
# 7042           No         No        No         No
# ...           ...        ...       ...        ...
# 667425         No         No        No         No
# 673105         No         No        No         No
# 674016         No         No        No         No
# 681736         No         No        No         No
# 682788         No         No        No         No
#
# [245 rows x 19 columns]

# %%
tree_census_subset = tree_census_subset[(tree_census_subset['tree_dbh']<=60) & (tree_census_subset['stump_diam']<=60)]

# %%
tree_census_subset
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum    1or2  NoDamage   Stones
# 1                        Quercus palustris    1or2    Damage   Stones
# 2       Gleditsia triacanthos var. inermis    1or2    Damage   Stones
# 3       Gleditsia triacanthos var. inermis    1or2    Damage   Stones
# 4                          Tilia americana    1or2    Damage   Stones
# ...                                    ...     ...       ...      ...
# 683783                   Quercus palustris    1or2    Damage   Stones
# 683784                 Cladrastis kentukea    1or2  NoDamage   Stones
# 683785                         Acer rubrum    1or2    Damage   Stones
# 683786                         Acer rubrum    1or2  NoDamage   Stones
# 683787                         Acer rubrum    1or2  NoDamage   Stones
#
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 0              No         No         No         No         No         No
# 1             Yes         No         No         No         No         No
# 2              No         No         No         No         No         No
# 3             Yes         No         No         No         No         No
# 4             Yes         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 683783         No         No         No         No         No         No
# 683784         No         No         No         No         No         No
# 683785         No         No         No         No         No         No
# 683786         No         No         No         No         No         No
# 683787         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other
# 0              No        No         No
# 1              No        No         No
# 2              No        No         No
# 3              No        No         No
# 4              No        No         No
# ...           ...       ...        ...
# 683783         No        No         No
# 683784         No        No         No
# 683785         No        No         No
# 683786         No        No         No
# 683787         No        No         No
#
# [683543 rows x 19 columns]

# %%
tree_census_subset_alive = tree_census_subset[tree_census_subset['status'] == 'Alive']
tree_census_dead_or_stump = tree_census_subset[(tree_census_subset['status'] == 'Dead') | (tree_census_subset['status'] == 'Stump')]

# %%
tree_census_subset_alive.groupby('spc_latin')[['tree_dbh', 'stump_diam']].mean()
# Out:
#                     tree_dbh  stump_diam
# spc_latin
# Acer               11.675424         0.0
# Acer buergerianum   8.090909         0.0
# Acer campestre      7.103962         0.0
# Acer ginnala        7.869204         0.0
# Acer griseum        3.509091         0.0
# ...                      ...         ...
# Tsuga canadensis    5.193182         0.0
# Ulmus americana    11.933768         0.0
# Ulmus parvifolia    7.396894         0.0
# Ulmus pumila       11.305712         0.0
# Zelkova serrata     7.842478         0.0
#
# [133 rows x 2 columns]

# %%
tree_census_subset_alive.groupby('spc_latin')['tree_dbh'].describe()
# Out:
#                      count       mean       std  min  25%   50%   75%   max
# spc_latin
# Acer                7080.0  11.675424  6.577626  0.0  7.0  11.0  15.0  59.0
# Acer buergerianum    110.0   8.090909  4.544470  2.0  5.0   8.0  10.0  28.0
# Acer campestre      2549.0   7.103962  4.293100  0.0  4.0   6.0   9.0  35.0
# Acer ginnala        2049.0   7.869204  4.853365  0.0  4.0   7.0  10.0  40.0
# Acer griseum         220.0   3.509091  3.578846  1.0  2.0   2.0   3.0  30.0
# ...                    ...        ...       ...  ...  ...   ...   ...   ...
# Tsuga canadensis      88.0   5.193182  3.959153  0.0  2.0   3.5   7.0  21.0
# Ulmus americana     7972.0  11.933768  9.374470  0.0  4.0   9.0  17.0  58.0
# Ulmus parvifolia    5344.0   7.396894  5.669532  0.0  3.0   5.0  10.0  53.0
# Ulmus pumila        1593.0  11.305712  8.665334  1.0  4.0   9.0  17.0  58.0
# Zelkova serrata    29253.0   7.842478  5.006273  0.0  4.0   6.0  11.0  58.0
#
# [133 rows x 8 columns]

# %%
tree_census_subset_alive[tree_census_subset_alive['tree_dbh'] == 0]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 5312      38793         0           0          OnCurb  Alive   Good
# 30524    204988         0           0          OnCurb  Alive   Good
# 44772    241329         0           0  OffsetFromCurb  Alive   Good
# 47154    173248         0           0          OnCurb  Alive   Good
# 47484    204173         0           0          OnCurb  Alive   Poor
# ...         ...       ...         ...             ...    ...    ...
# 658977   162280         0           0          OnCurb  Alive   Poor
# 671073    17796         0           0          OnCurb  Alive   Fair
# 671971   120612         0           0          OnCurb  Alive   Good
# 672443   116239         0           0          OnCurb  Alive   Good
# 680530    51015         0           0          OnCurb  Alive   Good
#
#                    spc_latin steward  sidewalk problems root_stone root_grate  \
# 5312       Cotinus coggygria    3or4    Damage   Stones         No         No
# 30524        Quercus phellos    1or2  NoDamage   Stones         No         No
# 44772                  Malus    1or2  NoDamage   Stones         No         No
# 47154        Quercus bicolor    1or2  NoDamage   Stones         No         No
# 47484            Picea abies    1or2  NoDamage   Stones         No         No
# ...                      ...     ...       ...      ...        ...        ...
# 658977       Quercus bicolor    1or2    Damage   Stones         No         No
# 671073    Taxodium distichum    1or2  NoDamage   Stones        Yes         No
# 671971  Juniperus virginiana    1or2  NoDamage   Stones         No         No
# 672443         Acer palmatum    1or2  NoDamage   Stones         No         No
# 680530         Acer palmatum    1or2  NoDamage   Stones         No         No
#
#        root_other trunk_wire trnk_light trnk_other brch_light brch_shoe  \
# 5312           No         No         No         No         No        No
# 30524          No         No         No         No         No        No
# 44772          No         No         No         No         No        No
# 47154          No         No         No         No         No        No
# 47484          No         No         No         No         No        No
# ...           ...        ...        ...        ...        ...       ...
# 658977         No         No         No         No         No        No
# 671073         No         No         No         No         No        No
# 671971         No         No         No         No         No        No
# 672443         No         No         No         No         No        No
# 680530         No         No         No         No         No        No
#
#        brch_other
# 5312           No
# 30524          No
# 44772          No
# 47154          No
# 47484          No
# ...           ...
# 658977         No
# 671073         No
# 671971         No
# 672443         No
# 680530         No
#
# [222 rows x 19 columns]

# %%
stats_alive = tree_census_subset_alive.groupby('spc_latin')['tree_dbh'].describe().reset_index()[['spc_latin', '25%', '75%']]
stats_alive
# Out:
#              spc_latin  25%   75%
# 0                 Acer  7.0  15.0
# 1    Acer buergerianum  5.0  10.0
# 2       Acer campestre  4.0   9.0
# 3         Acer ginnala  4.0  10.0
# 4         Acer griseum  2.0   3.0
# ..                 ...  ...   ...
# 128   Tsuga canadensis  2.0   7.0
# 129    Ulmus americana  4.0  17.0
# 130   Ulmus parvifolia  3.0  10.0
# 131       Ulmus pumila  4.0  17.0
# 132    Zelkova serrata  4.0  11.0
#
# [133 rows x 3 columns]

# %%
tree_census_subset_alive.merge(stats_alive, on='spc_latin', how='left')
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 652018   155433        25           0   OnCurb  Alive   Good
# 652019   183795         7           0   OnCurb  Alive   Good
# 652020   166161        12           0   OnCurb  Alive   Good
# 652021   184028         9           0   OnCurb  Alive   Good
# 652022   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum    1or2  NoDamage   Stones
# 1                        Quercus palustris    1or2    Damage   Stones
# 2       Gleditsia triacanthos var. inermis    1or2    Damage   Stones
# 3       Gleditsia triacanthos var. inermis    1or2    Damage   Stones
# 4                          Tilia americana    1or2    Damage   Stones
# ...                                    ...     ...       ...      ...
# 652018                   Quercus palustris    1or2    Damage   Stones
# 652019                 Cladrastis kentukea    1or2  NoDamage   Stones
# 652020                         Acer rubrum    1or2    Damage   Stones
# 652021                         Acer rubrum    1or2  NoDamage   Stones
# 652022                         Acer rubrum    1or2  NoDamage   Stones
#
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 0              No         No         No         No         No         No
# 1             Yes         No         No         No         No         No
# 2              No         No         No         No         No         No
# 3             Yes         No         No         No         No         No
# 4             Yes         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 652018         No         No         No         No         No         No
# 652019         No         No         No         No         No         No
# 652020         No         No         No         No         No         No
# 652021         No         No         No         No         No         No
# 652022         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other  25%   75%
# 0              No        No         No  5.0  14.0
# 1              No        No         No  8.0  24.0
# 2              No        No         No  6.0  13.0
# 3              No        No         No  6.0  13.0
# 4              No        No         No  4.0  12.0
# ...           ...       ...        ...  ...   ...
# 652018         No        No         No  8.0  24.0
# 652019         No        No         No  3.0   5.0
# 652020         No        No         No  5.0  14.0
# 652021         No        No         No  5.0  14.0
# 652022         No        No         No  5.0  14.0
#
# [652023 rows x 21 columns]

# %%
tree_census_subset_alive = tree_census_subset_alive.merge(stats_alive, on='spc_latin', how='left')

# %%
mask = tree_census_subset_alive['tree_dbh']<tree_census_subset_alive['25%']
tree_census_subset_alive.loc[mask, 'tree_dbh'] = tree_census_subset_alive['25%']

mask = tree_census_subset_alive['tree_dbh']>tree_census_subset_alive['75%']
tree_census_subset_alive.loc[mask, 'tree_dbh'] = tree_census_subset_alive['75%']
# Out:
# /tmp/ipython-input-2951236052.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 5.  6. 16. ...  8. 16.  8.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   tree_census_subset_alive.loc[mask, 'tree_dbh'] = tree_census_subset_alive['25%']

# %%
tree_census_subset_alive
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683       5.0           0   OnCurb  Alive   Fair
# 1        200540      21.0           0   OnCurb  Alive   Fair
# 2        204026       6.0           0   OnCurb  Alive   Good
# 3        204337      10.0           0   OnCurb  Alive   Good
# 4        189565      12.0           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 652018   155433      24.0           0   OnCurb  Alive   Good
# 652019   183795       5.0           0   OnCurb  Alive   Good
# 652020   166161      12.0           0   OnCurb  Alive   Good
# 652021   184028       9.0           0   OnCurb  Alive   Good
# 652022   200607      14.0           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum    1or2  NoDamage   Stones
# 1                        Quercus palustris    1or2    Damage   Stones
# 2       Gleditsia triacanthos var. inermis    1or2    Damage   Stones
# 3       Gleditsia triacanthos var. inermis    1or2    Damage   Stones
# 4                          Tilia americana    1or2    Damage   Stones
# ...                                    ...     ...       ...      ...
# 652018                   Quercus palustris    1or2    Damage   Stones
# 652019                 Cladrastis kentukea    1or2  NoDamage   Stones
# 652020                         Acer rubrum    1or2    Damage   Stones
# 652021                         Acer rubrum    1or2  NoDamage   Stones
# 652022                         Acer rubrum    1or2  NoDamage   Stones
#
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 0              No         No         No         No         No         No
# 1             Yes         No         No         No         No         No
# 2              No         No         No         No         No         No
# 3             Yes         No         No         No         No         No
# 4             Yes         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 652018         No         No         No         No         No         No
# 652019         No         No         No         No         No         No
# 652020         No         No         No         No         No         No
# 652021         No         No         No         No         No         No
# 652022         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other  25%   75%
# 0              No        No         No  5.0  14.0
# 1              No        No         No  8.0  24.0
# 2              No        No         No  6.0  13.0
# 3              No        No         No  6.0  13.0
# 4              No        No         No  4.0  12.0
# ...           ...       ...        ...  ...   ...
# 652018         No        No         No  8.0  24.0
# 652019         No        No         No  3.0   5.0
# 652020         No        No         No  5.0  14.0
# 652021         No        No         No  5.0  14.0
# 652022         No        No         No  5.0  14.0
#
# [652023 rows x 21 columns]
